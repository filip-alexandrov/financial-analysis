# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
from ast import literal_eval
import json

# %%
df = pd.read_json('trades_check.json')

# %%
profit = df['profit']
balance = df['startBalance']
print(profit.max())
print(balance.max())
print(profit.sum())
# Out:
# 1455.13373476796
# 28304.49019238385

# %%
sns.set_style('whitegrid')
sns.set_context('paper', font_scale=2)
sns.lineplot(data=profit)
# Out:
# <AxesSubplot:ylabel='profit'>

# %%
sns.set_style('whitegrid')
sns.set_context('paper', font_scale=2)
sns.lineplot(data=balance)
# Out:
# <AxesSubplot:ylabel='startBalance'>
